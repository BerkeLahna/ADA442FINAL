# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
df = pd.read_csv('bank-additional.csv', delimiter=';')
#data itself
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
# statistical info
#fundamentals of the data
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
# datatype info
#what is inside the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
# find unique values
df.apply(lambda x: len(x.unique()))
# Out:
# age                67
# job                12
# marital             4
# education           8
# default             3
# housing             3
# loan                3
# contact             2
# month              10
# day_of_week         5
# duration          828
# campaign           25
# pdays              21
# previous            7
# poutcome            3
# emp.var.rate       10
# cons.price.idx     26
# cons.conf.idx      26
# euribor3m         234
# nr.employed        11
# y                   2
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
# printing some graphs in order to understand the behaviour of the data and how it is distributed
plt.style.use('fivethirtyeight')
plt.figure(figsize=(13, 7))
sns.distplot(df['nr.employed'], bins=25)
# Out:
# <AxesSubplot:xlabel='nr.employed', ylabel='Density'>

# %%
sns.boxplot(df['nr.employed'])
plt.title("Boxplot of nr.employed")
plt.show()

# %%
# distribution of numeric variables
plt.figure(figsize=(20, 12))
sns.countplot(x = df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
#distribution of different jobs
plt.figure(figsize=(20, 12))
sns.countplot(x = df['job'])
# Out:
# <AxesSubplot:xlabel='job', ylabel='count'>

# %%
#in dataset the majority of people are married
sns.countplot(x = df['marital'])
# Out:
# <AxesSubplot:xlabel='marital', ylabel='count'>

# %%
#majority of people do not have a loan 
sns.countplot(x = df['loan'])
# Out:
# <AxesSubplot:xlabel='loan', ylabel='count'>

# %%
#most of the people in dataset have university degree
plt.figure(figsize=(20, 12))
sns.countplot(x = df['education'])
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
#majority of the peple use cellular to contact
sns.countplot(x = df['contact'])
# Out:
# <AxesSubplot:xlabel='contact', ylabel='count'>

# %%
#majority of the people have housing
sns.countplot(x = df['housing'])
# Out:
# <AxesSubplot:xlabel='housing', ylabel='count'>

# %%
sns.countplot(x = df['day_of_week'])
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='count'>

# %%
# bivariate analysis
#investigating the relationship between two variables (loan and age)
loan_age_pivot = df.pivot_table(index='age', columns='loan', aggfunc='size', fill_value=0)

# Plot the stacked bar chart
loan_age_pivot.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Loan Status by Age')
plt.legend(title='Loan', loc='upper right')
plt.show()

#majority of the people who are in 30s have loan.

# %%
# bivariate analysis
#investigating the relationship between two variables (term deposit subscription and age)
age_y_counts = df[['age', 'y']].copy()
age_y_counts = age_y_counts.groupby(['age', 'y']).size().unstack()
age_y_counts.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Term Deposit Subscription Count by Age')
plt.legend(title='Term Deposit Subscription')
plt.show()

#majority of the people who are in their 30s say yes to the term deposit

# %%
# bivariate analysis
#investigating the relationship between two variables (term deposit and job)
job_y_counts = df[['job', 'y']].copy()
job_y_counts = job_y_counts.groupby(['job', 'y']).size().unstack()
job_y_counts.plot(kind='bar', stacked=True)
plt.xlabel('Job')
plt.ylabel('Count')
plt.title('Term Deposit Subscription Count by Job')
plt.legend(title='Term Deposit Subscription')
plt.show()

#majority of the people who are admin say yes to term deposit

# %%
# bivariate analysis
#investigating the relationship between two variables (term deposit and loan)
loan_y_counts = df[['loan', 'y']].copy()
loan_y_counts = loan_y_counts.groupby(['loan', 'y']).size().unstack()
loan_y_counts.plot(kind='bar', stacked=True)
plt.xlabel('Loan')
plt.ylabel('Count')
plt.title('Term Deposit Subscription Count by Loan')
plt.legend(title='Term Deposit Subscription')
plt.show()

#majority of the people who do not have a loan say yes to the term deposit

# %%
# bivariate analysis
#investigating the relationship between two variables (term deposit and housing)
housing_y_counts = df[['housing', 'y']].copy()
housing_y_counts = housing_y_counts.groupby(['housing', 'y']).size().unstack()
housing_y_counts.plot(kind='bar', stacked=True)
plt.xlabel('Housing')
plt.ylabel('Count')
plt.title('Term Deposit Subscription Count by Housing')
plt.legend(title='Term Deposit Subscription')
plt.show()

#majority of the people who have housing say yes to term deposit

# %%
# bivariate analysis
#investigating the relationship between two variables (term deposit and education)
education_y_counts = df[['education', 'y']].copy()
education_y_counts = education_y_counts.groupby(['education', 'y']).size().unstack()
education_y_counts.plot(kind='bar', stacked=True)
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Term Deposit Subscription Count by Education')
plt.legend(title='Term Deposit Subscription')
plt.show()

#majority of the people who have high education (university degree) say yes to term deposit

# %% [markdown]
# # Data Cleaning

# %%
# check for null values, check the missing values
df.replace('unknown', pd.NA, inplace=True)
df.isnull().sum()
# Out:
# age                 0
# job                39
# marital            11
# education         167
# default           803
# housing           105
# loan              105
# contact             0
# month               0
# day_of_week         0
# duration            0
# campaign            0
# pdays               0
# previous            0
# poutcome            0
# emp.var.rate        0
# cons.price.idx      0
# cons.conf.idx       0
# euribor3m           0
# nr.employed         0
# y                   0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.duplicated()
#check whether there are duplicated variables or not
# Out:
# 0       False
# 1       False
# 2       False
# 4       False
# 5       False
#         ...
# 4114    False
# 4115    False
# 4116    False
# 4117    False
# 4118    False
# Length: 3090, dtype: bool

# %% [markdown]
# # Creation of New Attributes

# %%
# age groups and corresponding labels
age_groups = {
    (0, 30): 'Young',
    (31, 60): 'Middle-aged',
    (61, 100): 'Senior'
}

# function to map age to age group
def map_age_group(age):
    for group, label in age_groups.items():
        if group[0] <= age <= group[1]:
            return label
    return 'Unknown'  # In case there are any missing or unexpected values

# Add the 'Age Group' column to the dataframe
df['Age Group'] = df['age'].map(map_age_group)

# Display the updated dataframe
df.head()
# Out:
#    age          job  marital          education default housing loan  \
# 0   30  blue-collar  married           basic.9y      no     yes   no
# 1   39     services   single        high.school      no      no   no
# 2   25     services  married        high.school      no     yes   no
# 4   47       admin.  married  university.degree      no     yes   no
# 5   32     services   single  university.degree      no      no   no
#
#      contact month day_of_week  ...  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...    999         0  nonexistent
# 1  telephone   may         fri  ...    999         0  nonexistent
# 2  telephone   jun         wed  ...    999         0  nonexistent
# 4   cellular   nov         mon  ...    999         0  nonexistent
# 5   cellular   sep         thu  ...    999         2      failure
#
#    emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# 0          -1.8         92.893          -46.2      1.313       5099.1  no
# ...

# %% [markdown]
# # Outliers

# %%
df.shape
# Out:
# (3090, 22)

# %%
from scipy import stats

#Calculate z-scores for each numerical column
numerical_columns = ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
                     'euribor3m', 'nr.employed']
z_scores = np.abs(stats.zscore(df[numerical_columns]))

#Define a threshold for outlier detection
threshold = 3

#Find rows with outliers
outlier_rows = np.any(z_scores > threshold, axis=1)

#Scale the outliers using median values of non-outlier data
non_outlier_data = df[~outlier_rows][numerical_columns]
scaled_outliers = np.median(non_outlier_data, axis=0)

#Replace outlier values with scaled values
df.loc[outlier_rows, numerical_columns] = scaled_outliers

#Check the shape of the dataframe after scaling outliers
print("Shape of the dataframe after scaling outliers:", df.shape)
# Out:
# Shape of the dataframe after scaling outliers: (3090, 22)

# %%
sns.boxplot(df['emp.var.rate'])
plt.title("Boxplot of emp.var.rate")
plt.show()

# %% [markdown]
# # Encoding

# %%
# label encoding
cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        1          2        0        1     0        0      6
# 1   39    7        2          3        0        0     0        1      6
# 2   25    7        1          3        0        1     0        1      4
# 4   47    0        1          6        0        1     0        0      7
# 5   32    7        2          6        0        0     0        0      9
#
#    day_of_week  ...  pdays  previous  poutcome  emp.var.rate  cons.price.idx  \
# 0            0  ...    999         0         1          -1.8          92.893
# 1            0  ...    999         0         1           1.1          93.994
# 2            4  ...    999         0         1           1.4          94.465
# 4            1  ...    999         0         1          -0.1          93.200
# 5            2  ...    999         2         0          -1.1          94.199
#
#    cons.conf.idx  euribor3m  nr.employed  y    Age Group
# ...

# %% [markdown]
# # Coorelation Matrix

# %%
corr = df.corr()
plt.figure(figsize=(30,20))
sns.heatmap(corr, annot=True, cmap='coolwarm')
#check whether the attributes and our target variable are relevant or not
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Training

# %%
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        1          2        0        1     0        0      6
# 1   39    7        2          3        0        0     0        1      6
# 2   25    7        1          3        0        1     0        1      4
# 4   47    0        1          6        0        1     0        0      7
# 5   32    7        2          6        0        0     0        0      9
#
#    day_of_week  ...  pdays  previous  poutcome  emp.var.rate  cons.price.idx  \
# 0            0  ...    999         0         1          -1.8          92.893
# 1            0  ...    999         0         1           1.1          93.994
# 2            4  ...    999         0         1           1.4          94.465
# 4            1  ...    999         0         1          -0.1          93.200
# 5            2  ...    999         2         0          -1.1          94.199
#
#    cons.conf.idx  euribor3m  nr.employed  y    Age Group
# ...

# %%
# Split the dataset into features (X) and target variable (y)
X = df.drop(columns=['y', 'Age Group'])
y = df['y']

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.pipeline import Pipeline

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the scalers to evaluate
scalers = [
    ('StandardScaler', StandardScaler()),
    ('MinMaxScaler', MinMaxScaler()),
    ('RobustScaler', RobustScaler()),
    ('Normalizer', Normalizer())
]

# Create the logistic regression classifier
model = LogisticRegression()

# Define the parameter grid for grid search
param_grid = {
    'model__C': [0.1, 1.0, 10.0],  # example parameter values to search over
    'model__penalty': ['l1', 'l2']
}

best_accuracy = 0.0
best_precision = 0.0
best_accuracy_scaler = None
best_precision_scaler = None

# Iterate over the scalers and perform grid search with cross-validation
for scaler_name, scaler in scalers:
    # Create a pipeline with scaler and model
    pipeline = Pipeline([
        ('scaler', scaler),
        ('model', model)
    ])
    
    # Perform grid search with cross-validation
    grid_search = GridSearchCV(pipeline, param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # Get the best model and its hyperparameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    # Make predictions on the test set using the best model
    y_pred = best_model.predict(X_test)

    # Calculate the accuracy using the scaler
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, pos_label=1)
    print('Accuracy with', scaler_name, ':', accuracy)
    print('Precision with', scaler_name, ':', precision)
    
    # Check if the current scaler gives a better accuracy
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_accuracy_scaler = scaler_name
        
    # Check if the current scaler gives a better precision
    if precision > best_precision:
        best_precision = precision
        best_precision_scaler = scaler_name

print()
print('Best scaler for accuracy is', best_accuracy_scaler)
print('Best accuracy score is', best_accuracy)
print('Best scaler for precision is', best_precision_scaler)
print('Best precision score is', best_precision)
# Out:
# Accuracy with StandardScaler : 0.9212513484358145
# Precision with StandardScaler : 0.6779661016949152
# Accuracy with MinMaxScaler : 0.918015102481122
# Precision with MinMaxScaler : 0.65
# Accuracy with RobustScaler : 0.9212513484358145
# Precision with RobustScaler : 0.6615384615384615
# Accuracy with Normalizer : 0.9137001078748651
# Precision with Normalizer : 0.6842105263157895
#
# Best scaler for accuracy is StandardScaler
# Best accuracy score is 0.9212513484358145
# Best scaler for precision is Normalizer
# Best precision score is 0.6842105263157895

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.pipeline import Pipeline

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the scalers to evaluate
scalers = [
    ('StandardScaler', StandardScaler()),
    ('MinMaxScaler', MinMaxScaler()),
    ('RobustScaler', RobustScaler()),
    ('Normalizer', Normalizer())
]

# Create the MLP classifier
model = MLPClassifier()

# Define the parameter grid for grid search
param_grid = {
    'model__hidden_layer_sizes': [(100,), (50, 50), (25, 25, 25)],  # example parameter values to search over
    'model__activation': ['relu', 'tanh'],
    'model__alpha': [0.0001, 0.001, 0.01]
}

best_accuracy = 0.0
best_precision = 0.0
best_accuracy_scaler = None
best_precision_scaler = None

# Iterate over the scalers and perform grid search with cross-validation
for scaler_name, scaler in scalers:
    # Create a pipeline with scaler and model
    pipeline = Pipeline([
        ('scaler', scaler),
        ('model', model)
    ])
    
    # Perform grid search with cross-validation
    grid_search = GridSearchCV(pipeline, param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # Get the best model and its hyperparameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    # Make predictions on the test set using the best model
    y_pred = best_model.predict(X_test)

    # Calculate the accuracy using the scaler
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, pos_label=1)
    print('Accuracy with', scaler_name, ':', accuracy)
    print('Precision with', scaler_name, ':', precision)
    # Check if the current scaler gives a better accuracy
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_accuracy_scaler = scaler_name
        
    # Check if the current scaler gives a better precision
    if precision > best_precision:
        best_precision = precision
        best_precision_scaler = scaler_name

print()
print('Best scaler for accuracy is', best_accuracy_scaler)
print('Best accuracy score is', best_accuracy)
print('Best scaler for precision is', best_precision_scaler)
print('Best precision score is', best_precision)
# Out:
# Accuracy with StandardScaler : 0.9072276159654801
# Precision with StandardScaler : 0.5512820512820513
# Accuracy with MinMaxScaler : 0.9201725997842503
# Precision with MinMaxScaler : 0.6612903225806451
# Accuracy with RobustScaler : 0.9039913700107874
# Precision with RobustScaler : 0.5531914893617021
# Accuracy with Normalizer : 0.912621359223301
# Precision with Normalizer : 0.6382978723404256
#
# Best scaler for accuracy is MinMaxScaler
# Best accuracy score is 0.9201725997842503
# Best scaler for precision is MinMaxScaler
# Best precision score is 0.6612903225806451

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.pipeline import Pipeline


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the scalers to evaluate
scalers = [
    ('StandardScaler', StandardScaler()),
    ('MinMaxScaler', MinMaxScaler()),
    ('RobustScaler', RobustScaler()),
    ('Normalizer', Normalizer())
]

# Create the XGBoost classifier
model = XGBClassifier()

# Define the parameter grid for grid search
param_grid = {
    'model__learning_rate': [0.1, 0.01, 0.001],  # example parameter values to search over
    'model__max_depth': [3, 5, 7]
}

best_accuracy = 0.0
best_precision = 0.0
best_accuracy_scaler = None
best_precision_scaler = None

# Iterate over the scalers and perform grid search with cross-validation
for scaler_name, scaler in scalers:
    # Create a pipeline with scaler and model
    pipeline = Pipeline([
        ('scaler', scaler),
        ('model', model)
    ])
    
    # Perform grid search with cross-validation
    grid_search = GridSearchCV(pipeline, param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # Get the best model and its hyperparameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    # Make predictions on the test set using the best model
    y_pred = best_model.predict(X_test)

    # Calculate the accuracy using the scaler
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, pos_label=1)
    print('Accuracy with', scaler_name, ':', accuracy)
    print('Precision with', scaler_name, ':', precision)

    # Check if the current scaler gives a better accuracy
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_accuracy_scaler = scaler_name
        
    # Check if the current scaler gives a better precision
    if precision > best_precision:
        best_precision = precision
        best_precision_scaler = scaler_name

print()
print('Best scaler for accuracy is', best_accuracy_scaler)
print('Best accuracy score is', best_accuracy)
print('Best scaler for precision is', best_precision_scaler)
print('Best precision score is', best_precision)
# Out:
# Accuracy with StandardScaler : 0.9137001078748651
# Precision with StandardScaler : 0.5686274509803921
# Accuracy with MinMaxScaler : 0.9137001078748651
# Precision with MinMaxScaler : 0.5686274509803921
# Accuracy with RobustScaler : 0.9137001078748651
# Precision with RobustScaler : 0.5686274509803921
# Accuracy with Normalizer : 0.9072276159654801
# Precision with Normalizer : 0.5425531914893617
#
# Best scaler for accuracy is StandardScaler
# Best accuracy score is 0.9137001078748651
# Best scaler for precision is StandardScaler
# Best precision score is 0.5686274509803921

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.pipeline import Pipeline

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the scalers to evaluate
scalers = [
    ('StandardScaler', StandardScaler()),
    ('MinMaxScaler', MinMaxScaler()),
    ('RobustScaler', RobustScaler()),
    ('Normalizer', Normalizer())
]

# Create the Gradient Boosting classifier
model = GradientBoostingClassifier()

# Define the parameter grid for grid search
param_grid = {
    'model__n_estimators': [50, 100, 200],
    'model__learning_rate': [0.1, 0.01, 0.001],
    'model__max_depth': [3, 5, 7]
}

best_accuracy = 0.0
best_precision = 0.0
best_accuracy_scaler = None
best_precision_scaler = None

# Iterate over the scalers and perform grid search with cross-validation
for scaler_name, scaler in scalers:
    # Create a pipeline with scaler and model
    pipeline = Pipeline([
        ('scaler', scaler),
        ('model', model)
    ])
    
    # Perform grid search with cross-validation
    grid_search = GridSearchCV(pipeline, param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # Get the best model and its hyperparameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    # Make predictions on the test set using the best model
    y_pred = best_model.predict(X_test)

    # Calculate the accuracy using the scaler
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, pos_label=1)
    print('Accuracy with', scaler_name, ':', accuracy)
    print('Precision with', scaler_name, ':', precision)

    # Check if the current scaler gives a better accuracy
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_accuracy_scaler = scaler_name
        
    # Check if the current scaler gives a better precision
    if precision > best_precision:
        best_precision = precision
        best_precision_scaler = scaler_name

print()
print('Best scaler for accuracy is', best_accuracy_scaler)
print('Best accuracy score is', best_accuracy)
print('Best scaler for precision is', best_precision_scaler)
print('Best precision score is', best_precision)
# Out:
# Accuracy with StandardScaler : 0.9137001078748651
# Precision with StandardScaler : 0.5897435897435898
# Accuracy with MinMaxScaler : 0.9147788565264293
# Precision with MinMaxScaler : 0.5842696629213483
# Accuracy with RobustScaler : 0.9147788565264293
# Precision with RobustScaler : 0.5842696629213483
# Accuracy with Normalizer : 0.9158576051779935
# Precision with Normalizer : 0.5869565217391305
#
# Best scaler for accuracy is Normalizer
# Best accuracy score is 0.9158576051779935
# Best scaler for precision is StandardScaler
# Best precision score is 0.5897435897435898

# %%
# !pip install lightgbm
from sklearn.model_selection import train_test_split, GridSearchCV
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.pipeline import Pipeline

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the scalers to evaluate
scalers = [
    ('StandardScaler', StandardScaler()),
    ('MinMaxScaler', MinMaxScaler()),
    ('RobustScaler', RobustScaler()),
    ('Normalizer', Normalizer())
]

# Create the LGBM classifier
model = LGBMClassifier()

# Define the parameter grid for grid search
param_grid = {
    'model__num_leaves': [20, 30, 40],
    'model__learning_rate': [0.1, 0.01, 0.001],
    'model__n_estimators': [50, 100, 200]
}

best_accuracy = 0.0
best_precision = 0.0
best_accuracy_scaler = None
best_precision_scaler = None

# Iterate over the scalers and perform grid search with cross-validation
for scaler_name, scaler in scalers:
    # Create a pipeline with scaler and model
    pipeline = Pipeline([
        ('scaler', scaler),
        ('model', model)
    ])
    
    # Perform grid search with cross-validation
    grid_search = GridSearchCV(pipeline, param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # Get the best model and its hyperparameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    # Make predictions on the test set using the best model
    y_pred = best_model.predict(X_test)

    # Calculate the accuracy using the scaler
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, pos_label=1)
    print('Accuracy with', scaler_name, ':', accuracy)
    print('Precision with', scaler_name, ':', precision)

    # Check if the current scaler gives a better accuracy
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_accuracy_scaler = scaler_name
        
    # Check if the current scaler gives a better precision
    if precision > best_precision:
        best_precision = precision
        best_precision_scaler = scaler_name

print()
print('Best scaler for accuracy is', best_accuracy_scaler)
print('Best accuracy score is', best_accuracy)
print('Best scaler for precision is', best_precision_scaler)
print('Best precision score is', best_precision)
# Out:
# ...
# Accuracy with StandardScaler : 0.9137001078748651
# Precision with StandardScaler : 0.5875
# Accuracy with MinMaxScaler : 0.912621359223301
# Precision with MinMaxScaler : 0.5802469135802469
# Accuracy with RobustScaler : 0.9115426105717368
# Precision with RobustScaler : 0.573170731707317
# Accuracy with Normalizer : 0.9147788565264293
# Precision with Normalizer : 0.5974025974025974
#
# Best scaler for accuracy is Normalizer
# Best accuracy score is 0.9147788565264293
# Best scaler for precision is Normalizer
# Best precision score is 0.5974025974025974

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.pipeline import Pipeline

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the scalers to evaluate
scalers = [
    ('StandardScaler', StandardScaler()),
    ('MinMaxScaler', MinMaxScaler()),
    ('RobustScaler', RobustScaler()),
    ('Normalizer', Normalizer())
]

# Create the Decision Tree classifier
model = DecisionTreeClassifier()

# Define the parameter grid for grid search
param_grid = {
    'model__criterion': ['gini', 'entropy'],
    'model__max_depth': [None, 5, 10, 20],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}

best_accuracy = 0.0
best_precision = 0.0
best_accuracy_scaler = None
best_precision_scaler = None

# Iterate over the scalers and perform grid search with cross-validation
for scaler_name, scaler in scalers:
    # Create a pipeline with scaler and model
    pipeline = Pipeline([
        ('scaler', scaler),
        ('model', model)
    ])
    
    # Perform grid search with cross-validation
    grid_search = GridSearchCV(pipeline, param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # Get the best model and its hyperparameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    # Make predictions on the test set using the best model
    y_pred = best_model.predict(X_test)

    # Calculate the accuracy using the scaler
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, pos_label=1)
    print('Accuracy with', scaler_name, ':', accuracy)
    print('Precision with', scaler_name, ':', precision)

    # Check if the current scaler gives a better accuracy
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_accuracy_scaler = scaler_name
        
    # Check if the current scaler gives a better precision
    if precision > best_precision:
        best_precision = precision
        best_precision_scaler = scaler_name

print()
print('Best scaler for accuracy is', best_accuracy_scaler)
print('Best accuracy score is', best_accuracy)
print('Best scaler for precision is', best_precision_scaler)
print('Best precision score is', best_precision)
# Out:
# Accuracy with StandardScaler : 0.9137001078748651
# Precision with StandardScaler : 0.5673076923076923
# Accuracy with MinMaxScaler : 0.912621359223301
# Precision with MinMaxScaler : 0.5619047619047619
# Accuracy with RobustScaler : 0.9104638619201726
# Precision with RobustScaler : 0.5544554455445545
# Accuracy with Normalizer : 0.9039913700107874
# Precision with Normalizer : 0.5268817204301075
#
# Best scaler for accuracy is StandardScaler
# Best accuracy score is 0.9137001078748651
# Best scaler for precision is StandardScaler
# Best precision score is 0.5673076923076923

# %%
#Best Model is Logistic Regression
#Best scaler for accuracy is StandardScaler
#Best accuracy score is 0.9212513484358145
#Best scaler for precision is Normalizer
#Best precision score is 0.6842105263157895

# %%
# !pip install joblib
import joblib
# Save the final Bank classifier model as a pickle in a file
joblib.dump(best_model, "bank_model1.pkl")
# Out:
# ...
# ['bank_model1.pkl']

# %%
# !pipreqs
# Out:
# WARNING: requirements.txt already exists, use --force to overwrite it
